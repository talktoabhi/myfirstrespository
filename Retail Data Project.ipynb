# %%
# Importing Important Libraries
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
r_d_t = pd.read_csv('Retail_Data_Transactions.csv')
r_d_t.head()
# Out:
#   customer_id trans_date  tran_amount
# 0      CS5295  11-Feb-13           35
# 1      CS4768  15-Mar-15           39
# 2      CS2122  26-Feb-13           52
# 3      CS1217  16-Nov-11           99
# 4      CS1850  20-Nov-13           78
#   customer_id trans_date  tran_amount
# 0      CS5295  11-Feb-13           35
# 1      CS4768  15-Mar-15           39
# 2      CS2122  26-Feb-13           52
# 3      CS1217  16-Nov-11           99
# 4      CS1850  20-Nov-13           78

# %%
r_d_r=pd.read_csv('Retail_Data_Response.csv')
r_d_r.head()
# Out:
#   customer_id  response
# 0      CS1112         0
# 1      CS1113         0
# 2      CS1114         1
# 3      CS1115         1
# 4      CS1116         1
#   customer_id  response
# 0      CS1112         0
# 1      CS1113         0
# 2      CS1114         1
# 3      CS1115         1
# 4      CS1116         1

# %%
combine= r_d_t.merge(r_d_r, on='customer_id', how='left')
combine.head()
# Out:
#   customer_id trans_date  tran_amount  response
# 0      CS5295  11-Feb-13           35       1.0
# 1      CS4768  15-Mar-15           39       1.0
# 2      CS2122  26-Feb-13           52       0.0
# 3      CS1217  16-Nov-11           99       0.0
# 4      CS1850  20-Nov-13           78       0.0
#   customer_id trans_date  tran_amount  response
# 0      CS5295  11-Feb-13           35       1.0
# 1      CS4768  15-Mar-15           39       1.0
# 2      CS2122  26-Feb-13           52       0.0
# 3      CS1217  16-Nov-11           99       0.0
# 4      CS1850  20-Nov-13           78       0.0

# %%
combine.dtypes
# Out:
# customer_id     object
# trans_date      object
# tran_amount      int64
# response       float64
# dtype: object
# customer_id     object
# trans_date      object
# tran_amount      int64
# response       float64
# dtype: object

# %%
combine.shape
# Out:
# (125000, 4)
# (125000, 4)

# %%
combine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125000 entries, 0 to 124999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   customer_id  125000 non-null  object
#  1   trans_date   125000 non-null  object
#  2   tran_amount  125000 non-null  int64
#  3   response     124969 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125000 entries, 0 to 124999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   customer_id  125000 non-null  object
#  1   trans_date   125000 non-null  object
#  2   tran_amount  125000 non-null  int64
#  3   response     124969 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.8+ MB

# %%
combine.describe()
# Out:
#          tran_amount       response
# count  125000.000000  124969.000000
# mean       64.991912       0.110763
# std        22.860006       0.313840
# min        10.000000       0.000000
# 25%        47.000000       0.000000
# 50%        65.000000       0.000000
# 75%        83.000000       0.000000
# max       105.000000       1.000000
#          tran_amount       response
# count  125000.000000  124969.000000
# mean       64.991912       0.110763
# std        22.860006       0.313840
# min        10.000000       0.000000
# 25%        47.000000       0.000000
# 50%        65.000000       0.000000
# 75%        83.000000       0.000000
# max       105.000000       1.000000

# %%
combine.isnull().sum()
# Out:
# customer_id     0
# trans_date      0
# tran_amount     0
# response       31
# dtype: int64
# customer_id     0
# trans_date      0
# tran_amount     0
# response       31
# dtype: int64

# %%
combine=combine.dropna()

# %%
combine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124969 entries, 0 to 124999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   customer_id  124969 non-null  object
#  1   trans_date   124969 non-null  object
#  2   tran_amount  124969 non-null  int64
#  3   response     124969 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124969 entries, 0 to 124999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   customer_id  124969 non-null  object
#  1   trans_date   124969 non-null  object
#  2   tran_amount  124969 non-null  int64
#  3   response     124969 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.8+ MB

# %%
#Changing types of numerial Data into one
combine['response']= combine['response'].astype('int64')

# %%
#changing date types of data
combine['trans_date'] = pd.to_datetime(combine['trans_date'])

# %%
combine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124969 entries, 0 to 124999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   customer_id  124969 non-null  object
#  1   trans_date   124969 non-null  datetime64[ns]
#  2   tran_amount  124969 non-null  int64
#  3   response     124969 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 4.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124969 entries, 0 to 124999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   customer_id  124969 non-null  object
#  1   trans_date   124969 non-null  datetime64[ns]
#  2   tran_amount  124969 non-null  int64
#  3   response     124969 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 4.8+ MB

# %%
set(combine['response'])
# Out:
# {0, 1}
# {0, 1}

# %%
combine.dtypes
# Out:
# customer_id            object
# trans_date     datetime64[ns]
# tran_amount             int64
# response                int64
# dtype: object
# customer_id            object
# trans_date     datetime64[ns]
# tran_amount             int64
# response                int64
# dtype: object

# %%
# check for outliers
from scipy import stats

#calc z score
z_scores= np.abs(stats.zscore(combine['response']))
z_scores.head()
# Out:
# 0    2.833416
# 1    2.833416
# 2    0.352931
# 3    0.352931
# 4    0.352931
# Name: response, dtype: float64
# 0    2.833416
# 1    2.833416
# 2    0.352931
# 3    0.352931
# 4    0.352931
# Name: response, dtype: float64

# %%
#set a threshold

threshold= 3

outliers= z_scores>threshold


print(combine[outliers])
# Out:
# Empty DataFrame
# Columns: [customer_id, trans_date, tran_amount, response]
# Index: []
# Empty DataFrame
# Columns: [customer_id, trans_date, tran_amount, response]
# Index: []

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(combine['tran_amount'])
plt.show()

# %%
# creating new columns

combine['Month']= combine['trans_date'].dt.month

# %%
combine
# Out:
#        customer_id trans_date  tran_amount  response  Month
# 0           CS5295 2013-02-11           35         1      2
# 1           CS4768 2015-03-15           39         1      3
# 2           CS2122 2013-02-26           52         0      2
# 3           CS1217 2011-11-16           99         0     11
# 4           CS1850 2013-11-20           78         0     11
# ...            ...        ...          ...       ...    ...
# 124995      CS8433 2011-06-26           64         0      6
# 124996      CS7232 2014-08-19           38         0      8
# 124997      CS8731 2014-11-28           42         0     11
# 124998      CS8133 2013-12-14           13         0     12
# 124999      CS7996 2014-12-13           36         0     12
#
# [124969 rows x 5 columns]
#        customer_id trans_date  tran_amount  response  Month
# 0           CS5295 2013-02-11           35         1      2
# 1           CS4768 2015-03-15           39         1      3
# ...

# %%
# Which 3 months have had the highest transaction amounts?

monthly_Sales= combine.groupby('Month')['tran_amount'].sum()
monthly_Sales= monthly_Sales.sort_values(ascending=False).reset_index().head(5)
monthly_Sales
# Out:
#    Month  tran_amount
# 0      8       726775
# 1     10       725058
# 2      1       724089
# 3      7       717011
# 4     12       709795
#    Month  tran_amount
# 0      8       726775
# 1     10       725058
# 2      1       724089
# 3      7       717011
# 4     12       709795

# %%
sns.barplot(x='Month',y='tran_amount',data=monthly_Sales)
# Out:
# <Axes: xlabel='Month', ylabel='tran_amount'>
# <Axes: xlabel='Month', ylabel='tran_amount'>

# %%
# Customers having highest num of orders

customer_counts= combine['customer_id'].value_counts().reset_index()
customer_counts.columns=['customer_id','count']

# sort

top_5= customer_counts.sort_values(by='count', ascending=False).head(5)
top_5
# Out:
#   customer_id  count
# 0      CS4424     39
# 1      CS4320     38
# 2      CS3799     36
# 3      CS3013     35
# 4      CS1215     35
#   customer_id  count
# 0      CS4424     39
# 1      CS4320     38
# 2      CS3799     36
# 3      CS3013     35
# 4      CS1215     35

# %%
sns.barplot(x='customer_id',y='count',data=top_5)
# Out:
# <Axes: xlabel='customer_id', ylabel='count'>
# <Axes: xlabel='customer_id', ylabel='count'>

# %%
# Customers having highest value of orders

customer_sales = combine.groupby('customer_id')['tran_amount'].sum().reset_index()
customer_sales

# sort

top_5_sales= customer_sales.sort_values(by='tran_amount', ascending=False).head(5)
top_5_sales
# Out:
#      customer_id  tran_amount
# 3312      CS4424         2933
# 3208      CS4320         2647
# 4640      CS5752         2612
# 3548      CS4660         2527
# 2687      CS3799         2513
#      customer_id  tran_amount
# 3312      CS4424         2933
# 3208      CS4320         2647
# 4640      CS5752         2612
# 3548      CS4660         2527
# 2687      CS3799         2513

# %%
sns.barplot(x='customer_id',y='tran_amount',data=top_5_sales)
# Out:
# <Axes: xlabel='customer_id', ylabel='tran_amount'>
# <Axes: xlabel='customer_id', ylabel='tran_amount'>

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

combine['month_year'] = combine['trans_date'].dt.to_period('M')
monthly_sales = combine.groupby('month_year')['tran_amount'].sum()

# Convert the PeriodIndex to DateTimeIndex
monthly_sales.index = monthly_sales.index.to_timestamp()

plt.figure(figsize=(12,6))  # Increase the size of the figure
plt.plot(monthly_sales.index, monthly_sales.values)  # Plot the data
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # Format the x-axis labels
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))  # Set the x-axis interval
plt.xlabel('Month-Year')
plt.ylabel('Sales')
plt.title('Monthly Sales')
plt.xticks(rotation=45)  # Rotate the x-axis labels
plt.tight_layout()  # Adjust the layout for better visibility
plt.show()

# %%
combine['month_year'] = combine['trans_date'].dt.to_period('M')
monthly_sales = combine.groupby('month_year')['tran_amount'].sum()

# Convert the PeriodIndex to DateTimeIndex
monthly_sales.index = monthly_sales.index.to_timestamp()

plt.figure(figsize=(12,6))  # Increase the size of the figure
plt.plot(monthly_sales.index, monthly_sales.values)  # Plot the data
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # Format the x-axis labels
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))  # Set the x-axis interval
plt.xlabel('Month-Year')
plt.ylabel('Sales')
plt.title('Monthly Sales')
plt.xticks(rotation=45)  # Rotate the x-axis labels
plt.tight_layout()  # Adjust the layout for better visibility
plt.show()

# %%
# Recency will be the maximum of trans_date
recency = combine.groupby('customer_id')['trans_date'].max()

# Frequency will be the count of transactions
frequency = combine.groupby('customer_id')['trans_date'].count()

# Monetary will be the sum of tran_amount
monetary = combine.groupby('customer_id')['tran_amount'].sum()

# Combine all three into a DataFrame
rfm = pd.DataFrame({'recency': recency, 'frequency': frequency, 'monetary': monetary})

# %%
def segment_customer(row):
    if row['recency'].year >= 2012 and row['frequency'] >= 15 and row['monetary'] > 1000:
        return 'P0'
    elif (2011 <= row['recency'].year < 2012) and (10 < row['frequency'] <= 15) and (500 < row['monetary'] <= 1000):
        return 'P1'
    else:
        return 'P2'

rfm['Segment'] = rfm.apply(segment_customer, axis=1)

# %%
rfm
# Out:
#                recency  frequency  monetary Segment
# customer_id
# CS1112      2015-01-14         15      1012      P0
# CS1113      2015-02-09         20      1490      P0
# CS1114      2015-02-12         19      1432      P0
# CS1115      2015-03-05         22      1659      P0
# CS1116      2014-08-25         13       857      P2
# ...                ...        ...       ...     ...
# CS8996      2014-12-09         13       582      P2
# CS8997      2014-06-28         14       543      P2
# CS8998      2014-12-22         13       624      P2
# CS8999      2014-07-02         12       383      P2
# CS9000      2015-02-28         13       533      P2
#
# [6884 rows x 4 columns]
#                recency  frequency  monetary Segment
# customer_id
# CS1112      2015-01-14         15      1012      P0
# CS1113      2015-02-09         20      1490      P0
# CS1114      2015-02-12         19      1432      P0
# CS1115      2015-03-05         22      1659      P0
# ...

# %%
set(rfm['Segment'])
# here i didn't get the value of p1
# Out:
# {'P0', 'P2'}
# {'P0', 'P2'}

# %%
rfm['Segment'].value_counts()
# Out:
# P0    4423
# P2    2461
# Name: Segment, dtype: int64
# P0    4423
# P2    2461
# Name: Segment, dtype: int64

# %%
# Count the number of churned and active customers
churn_counts = combine['response'].value_counts()

# Plot
churn_counts.plot(kind='bar')
plt.title('Total Churn_counts Difference')
plt.xlabel('Response')
plt.ylabel('Counts')
plt.show()

# %%
# Top 5 customers
top_5_customers = monetary.sort_values(ascending=False).head(5).index

# Filter transactions of top 5 customers
top_customers_df = combine[combine['customer_id'].isin(top_5_customers)]

# Plot their monthly sales
top_customers_sales = top_customers_df.groupby(['customer_id', 'month_year'])['tran_amount'].sum().unstack(level=0)
top_customers_sales.plot(kind='line')
# Out:
# <Axes: xlabel='month_year'>
# <Axes: xlabel='month_year'>

# %%
combine.to_csv('Retail_Main_data.csv')

# %%
rfm.to_csv('Additional_Analysis.csv')
